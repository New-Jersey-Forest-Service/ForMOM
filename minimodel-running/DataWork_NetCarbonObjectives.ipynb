# %%
import pandas as pd
import numpy as np
import copy
from pprint import pprint

# %%
df = pd.read_excel('./run4_correctcarboncosts/AllCarbonNumbers_080922.xlsx')
num_rows = df.shape[0]
df.insert(0, 'Net_Carbon', [0] * num_rows)

START_YEAR = 2021
FOR_TYPES = list(set(df['StandID']))
YEARS = list(set(df['Year']))
MNGS = list(set(df['MgmtID']))

df.sort_values(['StandID', 'MgmtID', 'Year'])
# Out:
#     Net_Carbon        Variable StandID MgmtID  Year  Total_Stand_Carbon  \
# 0            0    505_2021_ASV     505    ASV  2021           55.202126
# 4            0    505_2025_ASV     505    ASV  2025           59.408627
# 8            0    505_2030_ASV     505    ASV  2030           63.405056
# 12           0    505_2050_ASV     505    ASV  2050           94.440681
# 1            0    505_2021_IFM     505    IFM  2021           52.616356
# 5            0    505_2025_IFM     505    IFM  2025           54.112751
# 9            0    505_2030_IFM     505    IFM  2030           57.430019
# 13           0    505_2050_IFM     505    IFM  2050           78.380608
# 2            0   505_2021_PLSQ     505   PLSQ  2021           55.080078
# 6            0   505_2025_PLSQ     505   PLSQ  2025           59.402340
# 10           0   505_2030_PLSQ     505   PLSQ  2030           64.457832
# 14           0   505_2050_PLSQ     505   PLSQ  2050           90.431480
# 3            0   505_2021_THNB     505   THNB  2021           53.693821
# 7            0   505_2025_THNB     505   THNB  2025           55.107147
# 11           0   505_2030_THNB     505   THNB  2030           58.010864
# 15           0   505_2050_THNB     505   THNB  2050           85.731613
# 16           0    608_2021_AWR     608    AWR  2021           27.277493
# 18           0    608_2025_AWR     608    AWR  2025           21.594889
# 20           0    608_2030_AWR     608    AWR  2030           21.131365
# 22           0    608_2050_AWR     608    AWR  2050           46.702976
# 17           0   608_2021_PLSQ     608   PLSQ  2021           45.944687
# 19           0   608_2025_PLSQ     608   PLSQ  2025           49.188103
# 21           0   608_2030_PLSQ     608   PLSQ  2030           52.375256
# 23           0   608_2050_PLSQ     608   PLSQ  2050           67.609947
# 24           0    999_2021_AWR     999    AWR  2021            4.822156
# 29           0    999_2025_AWR     999    AWR  2025            4.359046
# 34           0    999_2030_AWR     999    AWR  2030            6.590279
# 39           0    999_2050_AWR     999    AWR  2050           30.151794
# 25           0    999_2021_CAR     999    CAR  2021            4.822156
# 30           0    999_2025_CAR     999    CAR  2025            4.115263
# 35           0    999_2030_CAR     999    CAR  2030            4.938148
# 40           0    999_2050_CAR     999    CAR  2050           23.613348
# 26           0    999_2021_NAR     999    NAR  2021            4.824862
# 31           0    999_2025_NAR     999    NAR  2025            3.923987
# 36           0    999_2030_NAR     999    NAR  2030            4.108756
# 41           0    999_2050_NAR     999    NAR  2050           19.555927
# 27           0   999_2021_PLSQ     999   PLSQ  2021            7.028458
# 32           0   999_2025_PLSQ     999   PLSQ  2025            6.927432
# 37           0   999_2030_PLSQ     999   PLSQ  2030            7.025498
# 42           0   999_2050_PLSQ     999   PLSQ  2050            8.275467
# 28           0    999_2021_SAR     999    SAR  2021            4.822156
# 33           0    999_2025_SAR     999    SAR  2025            4.186758
# 38           0    999_2030_SAR     999    SAR  2030            5.298999
# 43           0    999_2050_SAR     999    SAR  2050           26.015049
# 44           0  167N_2021_PLSQ    167N   PLSQ  2021           35.021587
# 46           0  167N_2025_PLSQ    167N   PLSQ  2025           36.869949
# 48           0  167N_2030_PLSQ    167N   PLSQ  2030           36.483826
# 50           0  167N_2050_PLSQ    167N   PLSQ  2050           43.433018
# 45           0  167N_2021_THNB    167N   THNB  2021           34.437302
# 47           0  167N_2025_THNB    167N   THNB  2025           35.482277
# 49           0  167N_2030_THNB    167N   THNB  2030           36.572166
# 51           0  167N_2050_THNB    167N   THNB  2050           57.759636
# 52           0  167S_2021_PLSQ    167S   PLSQ  2021           37.369804
# 54           0  167S_2025_PLSQ    167S   PLSQ  2025           43.067703
# 56           0  167S_2030_PLSQ    167S   PLSQ  2030           49.113407
# 58           0  167S_2050_PLSQ    167S   PLSQ  2050           63.444649
# 53           0  167S_2021_THNB    167S   THNB  2021           36.438778
# 55           0  167S_2025_THNB    167S   THNB  2025           37.135593
# 57           0  167S_2030_THNB    167S   THNB  2030           38.280323
# 59           0  167S_2050_THNB    167S   THNB  2050           62.485512
#
#     Merch_Carbon_Stored
# 0              0.000083
# 4              0.179192
# 8              0.372516
# 12             1.162175
# 1              1.492325
# 5              1.235478
# 9              1.043617
# 13             0.803028
# 2              0.000000
# 6              0.000000
# 10             0.000000
# 14             0.000000
# 3              0.858615
# 7              0.685010
# 11             0.559091
# 15             0.418785
# 16            11.303518
# 18             9.906696
# 20             8.775704
# 22             6.953076
# 17             0.000000
# 19             0.000000
# 21             0.000000
# 23             0.000000
# 24             1.319345
# 29             1.158689
# 34             1.027353
# 39             0.810735
# 25             1.319345
# 30             1.158689
# 35             1.027353
# 40             0.810735
# 26             1.319345
# 31             1.158689
# 36             1.027353
# 41             0.810735
# 27             0.000000
# 32             0.000000
# 37             0.000000
# 42             0.000000
# 28             1.319345
# 33             1.158689
# 38             1.027353
# 43             0.810735
# 44             0.000000
# 46             0.000000
# 48             0.000000
# 50             0.000000
# 45             0.290956
# 47             0.224930
# 49             0.177456
# 51             0.126821
# 52             0.000000
# 54             0.000000
# 56             0.000000
# 58             0.000000
# 53             0.436180
# 55             0.328384
# 57             0.251331
# 59             0.171641

# %% [markdown]
# ## What We Want To Do
#  - 1) Turn stand carbon into net sequestration
#  - 2) Add harvested product
#  - 3) Subtract carbon costs

# %% [markdown]
# ## 1 - Net Sequestration
# We add a new column, net_carbon, which for each entry is equal to the net change in Total_Stand_Carbon from
# one year to the next.
#
# For 2021, we compare against the no management (PLSQ) for each forest type.

# %%
# Baseline extraction - we generate a dataframe which gives the Start Year PLSQ for each forest type
df_baseline = df[df['Year'] == START_YEAR]
df_baseline = df_baseline[df_baseline['MgmtID'] == 'PLSQ']

# We only care about these two columns
df_baseline = df_baseline[['Year', 'StandID', 'Total_Stand_Carbon']]
df_baseline = df_baseline.rename(columns={
    'Total_Stand_Carbon': 'Baseline_Carbon_2021'
})
df_baseline
# Out:
#     Year StandID  Baseline_Carbon_2021
# 2   2021     505             55.080078
# 17  2021     608             45.944687
# 27  2021     999              7.028458
# 44  2021    167N             35.021587
# 52  2021    167S             37.369804

# %%
# Calculate Net Carbon
# Step 1: Take difference between year to year

# This is achieved by sorting correctly, and then subtracting consecutive rows
# See: https://datagy.io/pandas-shift/
df_seq = df.sort_values(['StandID', 'MgmtID'])
df_seq['Shifted Carbon'] = df_seq['Total_Stand_Carbon'].shift(periods=1, fill_value=0)
df_seq['Net_Carbon'] = df_seq['Total_Stand_Carbon'] - df_seq['Shifted Carbon']
df_seq
# Out:
#     Net_Carbon        Variable StandID MgmtID  Year  Total_Stand_Carbon  \
# 0    55.202126    505_2021_ASV     505    ASV  2021           55.202126
# 4     4.206501    505_2025_ASV     505    ASV  2025           59.408627
# 8     3.996429    505_2030_ASV     505    ASV  2030           63.405056
# 12   31.035625    505_2050_ASV     505    ASV  2050           94.440681
# 1   -41.824326    505_2021_IFM     505    IFM  2021           52.616356
# 5     1.496395    505_2025_IFM     505    IFM  2025           54.112751
# 9     3.317268    505_2030_IFM     505    IFM  2030           57.430019
# 13   20.950588    505_2050_IFM     505    IFM  2050           78.380608
# 2   -23.300529   505_2021_PLSQ     505   PLSQ  2021           55.080078
# 6     4.322262   505_2025_PLSQ     505   PLSQ  2025           59.402340
# 10    5.055492   505_2030_PLSQ     505   PLSQ  2030           64.457832
# 14   25.973648   505_2050_PLSQ     505   PLSQ  2050           90.431480
# 3   -36.737659   505_2021_THNB     505   THNB  2021           53.693821
# 7     1.413326   505_2025_THNB     505   THNB  2025           55.107147
# 11    2.903717   505_2030_THNB     505   THNB  2030           58.010864
# 15   27.720749   505_2050_THNB     505   THNB  2050           85.731613
# 16  -58.454121    608_2021_AWR     608    AWR  2021           27.277493
# 18   -5.682604    608_2025_AWR     608    AWR  2025           21.594889
# 20   -0.463524    608_2030_AWR     608    AWR  2030           21.131365
# 22   25.571611    608_2050_AWR     608    AWR  2050           46.702976
# 17   -0.758289   608_2021_PLSQ     608   PLSQ  2021           45.944687
# 19    3.243416   608_2025_PLSQ     608   PLSQ  2025           49.188103
# 21    3.187153   608_2030_PLSQ     608   PLSQ  2030           52.375256
# 23   15.234692   608_2050_PLSQ     608   PLSQ  2050           67.609947
# 24  -62.787791    999_2021_AWR     999    AWR  2021            4.822156
# 29   -0.463110    999_2025_AWR     999    AWR  2025            4.359046
# 34    2.231233    999_2030_AWR     999    AWR  2030            6.590279
# 39   23.561516    999_2050_AWR     999    AWR  2050           30.151794
# 25  -25.329638    999_2021_CAR     999    CAR  2021            4.822156
# 30   -0.706893    999_2025_CAR     999    CAR  2025            4.115263
# 35    0.822885    999_2030_CAR     999    CAR  2030            4.938148
# 40   18.675200    999_2050_CAR     999    CAR  2050           23.613348
# 26  -18.788486    999_2021_NAR     999    NAR  2021            4.824862
# 31   -0.900875    999_2025_NAR     999    NAR  2025            3.923987
# 36    0.184769    999_2030_NAR     999    NAR  2030            4.108756
# 41   15.447171    999_2050_NAR     999    NAR  2050           19.555927
# 50             0.000000       36.483826
# 45             0.290956       43.433018
# 47             0.224930       34.437302
# 49             0.177456       35.482277
# 51             0.126821       36.572166
# 52             0.000000       57.759636
# 54             0.000000       37.369804
# 56             0.000000       43.067703
# 58             0.000000       49.113407
# 53             0.436180       63.444649
# 55             0.328384       36.438778
# 57             0.251331       37.135593
# 59             0.171641       38.280323

# %%
# Calculate Net Carbon
# Step 2: For 2021, subtract against PLSQ

# This adds a column with the 2021 PLSQ baseline numbers
df_seq = df_seq.merge(df_baseline, 
         how='left', 
         on=['Year', 'StandID'], 
         validate='many_to_one'
        )

df_seq['First_Year_Net_Carbon'] = df_seq['Total_Stand_Carbon'] - df_seq['Baseline_Carbon_2021']
df_seq['Net_Carbon'] = df_seq['First_Year_Net_Carbon'].fillna(df_seq['Net_Carbon'])
df_seq
# Out:
#     Net_Carbon        Variable StandID MgmtID  Year  Total_Stand_Carbon  \
# 0     0.122047    505_2021_ASV     505    ASV  2021           55.202126
# 1     4.206501    505_2025_ASV     505    ASV  2025           59.408627
# 2     3.996429    505_2030_ASV     505    ASV  2030           63.405056
# 3    31.035625    505_2050_ASV     505    ASV  2050           94.440681
# 4    -2.463722    505_2021_IFM     505    IFM  2021           52.616356
# 5     1.496395    505_2025_IFM     505    IFM  2025           54.112751
# 6     3.317268    505_2030_IFM     505    IFM  2030           57.430019
# 7    20.950588    505_2050_IFM     505    IFM  2050           78.380608
# 8     0.000000   505_2021_PLSQ     505   PLSQ  2021           55.080078
# 9     4.322262   505_2025_PLSQ     505   PLSQ  2025           59.402340
# 10    5.055492   505_2030_PLSQ     505   PLSQ  2030           64.457832
# 11   25.973648   505_2050_PLSQ     505   PLSQ  2050           90.431480
# 12   -1.386257   505_2021_THNB     505   THNB  2021           53.693821
# 13    1.413326   505_2025_THNB     505   THNB  2025           55.107147
# 14    2.903717   505_2030_THNB     505   THNB  2030           58.010864
# 15   27.720749   505_2050_THNB     505   THNB  2050           85.731613
# 16  -18.667194    608_2021_AWR     608    AWR  2021           27.277493
# 17   -5.682604    608_2025_AWR     608    AWR  2025           21.594889
# 18   -0.463524    608_2030_AWR     608    AWR  2030           21.131365
# 19   25.571611    608_2050_AWR     608    AWR  2050           46.702976
# 20    0.000000   608_2021_PLSQ     608   PLSQ  2021           45.944687
# 21    3.243416   608_2025_PLSQ     608   PLSQ  2025           49.188103
# 22    3.187153   608_2030_PLSQ     608   PLSQ  2030           52.375256
# 23   15.234692   608_2050_PLSQ     608   PLSQ  2050           67.609947
# 24   -2.206302    999_2021_AWR     999    AWR  2021            4.822156
# 25   -0.463110    999_2025_AWR     999    AWR  2025            4.359046
# 26    2.231233    999_2030_AWR     999    AWR  2030            6.590279
# 27   23.561516    999_2050_AWR     999    AWR  2050           30.151794
# 28   -2.206302    999_2021_CAR     999    CAR  2021            4.822156
# 29   -0.706893    999_2025_CAR     999    CAR  2025            4.115263
# 30    0.822885    999_2030_CAR     999    CAR  2030            4.938148
# 31   18.675200    999_2050_CAR     999    CAR  2050           23.613348
# 32   -2.203596    999_2021_NAR     999    NAR  2021            4.824862
# 33   -0.900875    999_2025_NAR     999    NAR  2025            3.923987
# 34    0.184769    999_2030_NAR     999    NAR  2030            4.108756
# 35   15.447171    999_2050_NAR     999    NAR  2050           19.555927
# 36    0.000000   999_2021_PLSQ     999   PLSQ  2021            7.028458
# 37   -0.101026   999_2025_PLSQ     999   PLSQ  2025            6.927432
# 38    0.098066   999_2030_PLSQ     999   PLSQ  2030            7.025498
# 39    1.249969   999_2050_PLSQ     999   PLSQ  2050            8.275467
# 40   -2.206302    999_2021_SAR     999    SAR  2021            4.822156
# 41   -0.635398    999_2025_SAR     999    SAR  2025            4.186758
# 42    1.112241    999_2030_SAR     999    SAR  2030            5.298999
# 43   20.716050    999_2050_SAR     999    SAR  2050           26.015049
# 44    0.000000  167N_2021_PLSQ    167N   PLSQ  2021           35.021587
# 45    1.848362  167N_2025_PLSQ    167N   PLSQ  2025           36.869949
# 46   -0.386124  167N_2030_PLSQ    167N   PLSQ  2030           36.483826
# 47    6.949192  167N_2050_PLSQ    167N   PLSQ  2050           43.433018
# 48   -0.584286  167N_2021_THNB    167N   THNB  2021           34.437302
# 49    1.044975  167N_2025_THNB    167N   THNB  2025           35.482277
# 50    1.089890  167N_2030_THNB    167N   THNB  2030           36.572166
# 51   21.187469  167N_2050_THNB    167N   THNB  2050           57.759636
# 52    0.000000  167S_2021_PLSQ    167S   PLSQ  2021           37.369804
# 53    5.697899  167S_2025_PLSQ    167S   PLSQ  2025           43.067703
# 54    6.045704  167S_2030_PLSQ    167S   PLSQ  2030           49.113407
# 55   14.331242  167S_2050_PLSQ    167S   PLSQ  2050           63.444649
# 56   -0.931026  167S_2021_THNB    167S   THNB  2021           36.438778
# 57    0.696815  167S_2025_THNB    167S   THNB  2025           37.135593
# 58    1.144730  167S_2030_THNB    167S   THNB  2030           38.280323
# 59   24.205189  167S_2050_THNB    167S   THNB  2050           62.485512
#
#     Merch_Carbon_Stored  Shifted Carbon  Baseline_Carbon_2021  \
# 0              0.000083        0.000000             55.080078
# 1              0.179192       55.202126                   NaN
# 2              0.372516       59.408627                   NaN
# 3              1.162175       63.405056                   NaN
# 4              1.492325       94.440681             55.080078
# 5              1.235478       52.616356                   NaN
# 6              1.043617       54.112751                   NaN
# 7              0.803028       57.430019                   NaN
# 8              0.000000       78.380608             55.080078
# 9              0.000000       55.080078                   NaN
# 10             0.000000       59.402340                   NaN
# 11             0.000000       64.457832                   NaN
# 12             0.858615       90.431480             55.080078
# 13             0.685010       53.693821                   NaN
# 14             0.559091       55.107147                   NaN
# 15             0.418785       58.010864                   NaN
# 16            11.303518       85.731613             45.944687
# 17             9.906696       27.277493                   NaN
# 18             8.775704       21.594889                   NaN
# 19             6.953076       21.131365                   NaN
# 20             0.000000       46.702976             45.944687
# 21             0.000000       45.944687                   NaN
# 22             0.000000       49.188103                   NaN
# 23             0.000000       52.375256                   NaN
# 24             1.319345       67.609947              7.028458
# 25             1.158689        4.822156                   NaN
# 26             1.027353        4.359046                   NaN
# 27             0.810735        6.590279                   NaN
# 28             1.319345       30.151794              7.028458
# 29             1.158689        4.822156                   NaN
# 30             1.027353        4.115263                   NaN
# 31             0.810735        4.938148                   NaN
# 32             1.319345       23.613348              7.028458
# 33             1.158689        4.824862                   NaN
# 34             1.027353        3.923987                   NaN
# 35             0.810735        4.108756                   NaN
# 36             0.000000       19.555927              7.028458
# 37             0.000000        7.028458                   NaN
# 38             0.000000        6.927432                   NaN
# 39             0.000000        7.025498                   NaN
# 40             1.319345        8.275467              7.028458
# 41             1.158689        4.822156                   NaN
# 42             1.027353        4.186758                   NaN
# 43             0.810735        5.298999                   NaN
# 44             0.000000       26.015049             35.021587
# 45             0.000000       35.021587                   NaN
# 46             0.000000       36.869949                   NaN
# 47             0.000000       36.483826                   NaN
# 48             0.290956       43.433018             35.021587
# 49             0.224930       34.437302                   NaN
# 50             0.177456       35.482277                   NaN
# 51             0.126821       36.572166                   NaN
# 52             0.000000       57.759636             37.369804
# 53             0.000000       37.369804                   NaN
# 54             0.000000       43.067703                   NaN
# 55             0.000000       49.113407                   NaN
# 56             0.436180       63.444649             37.369804
# 57             0.328384       36.438778                   NaN
# 58             0.251331       37.135593                   NaN
# 59             0.171641       38.280323                   NaN
#
#     First_Year_Net_Carbon
# 0                0.122047
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4               -2.463722
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                0.000000
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12              -1.386257
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16             -18.667194
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 20               0.000000
# 21                    NaN
# 22                    NaN
# 23                    NaN
# 24              -2.206302
# 25                    NaN
# 26                    NaN
# 27                    NaN
# 28              -2.206302
# 29                    NaN
# 30                    NaN
# 31                    NaN
# 32              -2.203596
# 33                    NaN
# 34                    NaN
# 35                    NaN
# 36               0.000000
# 37                    NaN
# 38                    NaN
# 39                    NaN
# 40              -2.206302
# 41                    NaN
# 42                    NaN
# 43                    NaN
# 44               0.000000
# 45                    NaN
# 46                    NaN
# 47                    NaN
# 48              -0.584286
# 49                    NaN
# 50                    NaN
# 51                    NaN
# 52               0.000000
# 53                    NaN
# 54                    NaN
# 55                    NaN
# 56              -0.931026
# 57                    NaN
# 58                    NaN
# 59                    NaN

# %%
# Cleanup - remove now unnecessary rows
df_seq = df_seq.drop(columns=[
    'Shifted Carbon', 
    'Baseline_Carbon_2021', 
    'First_Year_Net_Carbon',
    'Total_Stand_Carbon'
])

# %%
# df_mgcost.to_csv('./ObjectiveFile_MngCost_0802022.csv',
#               columns=['Variable', 'Net_Carbon'],
#               index=False
#              )

df_seq.to_csv('./run4_correctcarboncosts/Objective_NetSeq_NoHarvest_08172022.csv',
             columns=['Variable', 'Net_Carbon'],
             index=False
             )

# %% [markdown]
# ## 2 - Add Carbon Harvest
# The Merch_Carbon_Stored column tells us how much carbon total has been stored.
# Some managements require management at the start, while some require continual managing.
#
# Cost Frequency:
#  - ASV: Every Cycle
#  - IFM: Once
#  - THNB: Once
#  - AWR: Once
#  - CAR: Once
#  - NAR: Once
#  - SAR: Once
#
# For a management that gets managed once, we add the final carbon stored to the 2021 figure.
# For ASV, we do it like Net Carbon, taking the new harvest carbon each year.
#
# It's not quite right to do ASV the same way, butttttt I will because I don't see how else to extract
# carbon numbers. Doing per cycle ignores the impact of carbon decay :/

# %%
once_costs = ['IFM', 'THNB', 'AWR', 'CAR', 'NAR', 'SAR']
repeated_costs = ['ASV']

# %%
df_hrv = copy.deepcopy(df_seq)
df_hrv.sort_values(['MgmtID', 'StandID', 'Year'])
# Out:
#     Net_Carbon        Variable StandID MgmtID  Year  Merch_Carbon_Stored
# 0     0.122047    505_2021_ASV     505    ASV  2021             0.000083
# 1     4.206501    505_2025_ASV     505    ASV  2025             0.179192
# 2     3.996429    505_2030_ASV     505    ASV  2030             0.372516
# 3    31.035625    505_2050_ASV     505    ASV  2050             1.162175
# 16  -18.667194    608_2021_AWR     608    AWR  2021            11.303518
# 17   -5.682604    608_2025_AWR     608    AWR  2025             9.906696
# 18   -0.463524    608_2030_AWR     608    AWR  2030             8.775704
# 19   25.571611    608_2050_AWR     608    AWR  2050             6.953076
# 24   -2.206302    999_2021_AWR     999    AWR  2021             1.319345
# 25   -0.463110    999_2025_AWR     999    AWR  2025             1.158689
# 26    2.231233    999_2030_AWR     999    AWR  2030             1.027353
# 27   23.561516    999_2050_AWR     999    AWR  2050             0.810735
# 28   -2.206302    999_2021_CAR     999    CAR  2021             1.319345
# 29   -0.706893    999_2025_CAR     999    CAR  2025             1.158689
# 30    0.822885    999_2030_CAR     999    CAR  2030             1.027353
# 31   18.675200    999_2050_CAR     999    CAR  2050             0.810735
# 4    -2.463722    505_2021_IFM     505    IFM  2021             1.492325
# 5     1.496395    505_2025_IFM     505    IFM  2025             1.235478
# 6     3.317268    505_2030_IFM     505    IFM  2030             1.043617
# 7    20.950588    505_2050_IFM     505    IFM  2050             0.803028
# 32   -2.203596    999_2021_NAR     999    NAR  2021             1.319345
# 33   -0.900875    999_2025_NAR     999    NAR  2025             1.158689
# 34    0.184769    999_2030_NAR     999    NAR  2030             1.027353
# 35   15.447171    999_2050_NAR     999    NAR  2050             0.810735
# 8     0.000000   505_2021_PLSQ     505   PLSQ  2021             0.000000
# 9     4.322262   505_2025_PLSQ     505   PLSQ  2025             0.000000
# 10    5.055492   505_2030_PLSQ     505   PLSQ  2030             0.000000
# 11   25.973648   505_2050_PLSQ     505   PLSQ  2050             0.000000
# 20    0.000000   608_2021_PLSQ     608   PLSQ  2021             0.000000
# 21    3.243416   608_2025_PLSQ     608   PLSQ  2025             0.000000
# 22    3.187153   608_2030_PLSQ     608   PLSQ  2030             0.000000
# 23   15.234692   608_2050_PLSQ     608   PLSQ  2050             0.000000
# 36    0.000000   999_2021_PLSQ     999   PLSQ  2021             0.000000
# 37   -0.101026   999_2025_PLSQ     999   PLSQ  2025             0.000000
# 38    0.098066   999_2030_PLSQ     999   PLSQ  2030             0.000000
# 39    1.249969   999_2050_PLSQ     999   PLSQ  2050             0.000000
# 44    0.000000  167N_2021_PLSQ    167N   PLSQ  2021             0.000000
# 45    1.848362  167N_2025_PLSQ    167N   PLSQ  2025             0.000000
# 46   -0.386124  167N_2030_PLSQ    167N   PLSQ  2030             0.000000
# 47    6.949192  167N_2050_PLSQ    167N   PLSQ  2050             0.000000
# 52    0.000000  167S_2021_PLSQ    167S   PLSQ  2021             0.000000
# 53    5.697899  167S_2025_PLSQ    167S   PLSQ  2025             0.000000
# 54    6.045704  167S_2030_PLSQ    167S   PLSQ  2030             0.000000
# 55   14.331242  167S_2050_PLSQ    167S   PLSQ  2050             0.000000
# 40   -2.206302    999_2021_SAR     999    SAR  2021             1.319345
# 41   -0.635398    999_2025_SAR     999    SAR  2025             1.158689
# 42    1.112241    999_2030_SAR     999    SAR  2030             1.027353
# 43   20.716050    999_2050_SAR     999    SAR  2050             0.810735
# 12   -1.386257   505_2021_THNB     505   THNB  2021             0.858615
# 13    1.413326   505_2025_THNB     505   THNB  2025             0.685010
# 14    2.903717   505_2030_THNB     505   THNB  2030             0.559091
# 15   27.720749   505_2050_THNB     505   THNB  2050             0.418785
# 48   -0.584286  167N_2021_THNB    167N   THNB  2021             0.290956
# 49    1.044975  167N_2025_THNB    167N   THNB  2025             0.224930
# 50    1.089890  167N_2030_THNB    167N   THNB  2030             0.177456
# 51   21.187469  167N_2050_THNB    167N   THNB  2050             0.126821
# 56   -0.931026  167S_2021_THNB    167S   THNB  2021             0.436180
# 57    0.696815  167S_2025_THNB    167S   THNB  2025             0.328384
# 58    1.144730  167S_2030_THNB    167S   THNB  2030             0.251331
# 59   24.205189  167S_2050_THNB    167S   THNB  2050             0.171641

# %%
# Step 1 - Extract 2050 harvest carbon numbers
df_hrv_2050 = df_hrv[df_hrv['Year'] == 2050]
# If you want to filter out ASV, uncomment the below
# df_hrv_2050 = df_hrv_2050[df_hrv_2050['MgmtID'] != 'ASV']

df_hrv_2050 = df_hrv_2050[['Year', 'StandID', 'MgmtID', 'Merch_Carbon_Stored']]
# As a cheat, we relabel the year to 2021 so it merges with 2021 years
df_hrv_2050 = df_hrv_2050.assign(Year = 2021)
df_hrv_2050 = df_hrv_2050.rename(columns={
    'Merch_Carbon_Stored': 'Carbon_Stored_2050'
})

df_hrv_2050
# Out:
#     Year StandID MgmtID  Carbon_Stored_2050
# 3   2021     505    ASV            1.162175
# 7   2021     505    IFM            0.803028
# 11  2021     505   PLSQ            0.000000
# 15  2021     505   THNB            0.418785
# 19  2021     608    AWR            6.953076
# 23  2021     608   PLSQ            0.000000
# 27  2021     999    AWR            0.810735
# 31  2021     999    CAR            0.810735
# 35  2021     999    NAR            0.810735
# 39  2021     999   PLSQ            0.000000
# 43  2021     999    SAR            0.810735
# 47  2021    167N   PLSQ            0.000000
# 51  2021    167N   THNB            0.126821
# 55  2021    167S   PLSQ            0.000000
# 59  2021    167S   THNB            0.171641

# %%
# Step 2 - Combine with actual df and add harvest to 2021 numbers
dup_hrv = copy.deepcopy(df_hrv)

dup_hrv = dup_hrv.merge(df_hrv_2050,
# 40   -1.395567    999_2021_SAR     999    SAR  2021             1.319345
# 41   -0.635398    999_2025_SAR     999    SAR  2025             1.158689
# 42    1.112241    999_2030_SAR     999    SAR  2030             1.027353
# 43   20.716050    999_2050_SAR     999    SAR  2050             0.810735
# 44    0.000000  167N_2021_PLSQ    167N   PLSQ  2021             0.000000
# 45    1.848362  167N_2025_PLSQ    167N   PLSQ  2025             0.000000
# 46   -0.386124  167N_2030_PLSQ    167N   PLSQ  2030             0.000000
# 47    6.949192  167N_2050_PLSQ    167N   PLSQ  2050             0.000000
# 48   -0.457464  167N_2021_THNB    167N   THNB  2021             0.290956
# 49    1.044975  167N_2025_THNB    167N   THNB  2025             0.224930
# 50    1.089890  167N_2030_THNB    167N   THNB  2030             0.177456
# 51   21.187469  167N_2050_THNB    167N   THNB  2050             0.126821
# 52    0.000000  167S_2021_PLSQ    167S   PLSQ  2021             0.000000
# 53    5.697899  167S_2025_PLSQ    167S   PLSQ  2025             0.000000
# 54    6.045704  167S_2030_PLSQ    167S   PLSQ  2030             0.000000
# 55   14.331242  167S_2050_PLSQ    167S   PLSQ  2050             0.000000
# 56   -0.759386  167S_2021_THNB    167S   THNB  2021             0.436180
# 57    0.696815  167S_2025_THNB    167S   THNB  2025             0.328384
# 58    1.144730  167S_2030_THNB    167S   THNB  2030             0.251331
# 59   24.205189  167S_2050_THNB    167S   THNB  2050             0.171641
#
#     Carbon_Stored_2050
# 0             1.162175
# 1             0.000000
# 2             0.000000
# 3             0.000000
# 4             0.803028
# 5             0.000000
# 6             0.000000
# 7             0.000000
# 8             0.000000
# 9             0.000000
# 10            0.000000
# 11            0.000000
# 12            0.418785
# 13            0.000000
# 14            0.000000
# 15            0.000000
# 16            6.953076
# 17            0.000000
# 18            0.000000
# 19            0.000000
# 20            0.000000
# 21            0.000000
# 22            0.000000
# 23            0.000000
# 24            0.810735
# 25            0.000000
# 26            0.000000
# 27            0.000000
# 28            0.810735
# 29            0.000000
# 30            0.000000
# 31            0.000000
# 32            0.810735
# 33            0.000000
# 34            0.000000
# 35            0.000000
# 36            0.000000
# 37            0.000000
# 38            0.000000
# 39            0.000000
# 40            0.810735
# 41            0.000000
# 42            0.000000
# 43            0.000000
# 44            0.000000
# 45            0.000000
# 46            0.000000
# 47            0.000000
# 48            0.126821
# 49            0.000000
# 50            0.000000
# 51            0.000000
# 52            0.000000
# 53            0.000000
# 54            0.000000
# 55            0.000000
# 56            0.171641
# 57            0.000000
# 58            0.000000
# 59            0.000000

# %%
# Step 3 - Do ASV harvest carbon (NOT DONE, COMMENT LEFT FOR REFERENCE)
#
# This should be systemized, but because it's a small # entries,
# I did it manually.
#
#   	Net_Carbon 	Variable     	StandID 	MgmtID 	Year 	Merch_Carbon_Stored 	Carbon_Stored_2050
# 0 	0.122047 	505_2021_ASV 	505     	ASV 	2021 	0.000083 	0.000000
# 1 	4.206501 	505_2025_ASV 	505     	ASV 	2025 	0.179192 	0.000000
# 2 	3.996429 	505_2030_ASV 	505     	ASV 	2030 	0.372516 	0.000000
# 3 	31.035625 	505_2050_ASV 	505     	ASV 	2050 	1.162175 	0.000000
# 
# So, merch_carbon for 2021 = 
#

# %%
df_hrv = dup_hrv.drop(columns=[
    'Carbon_Stored_2050', 'Merch_Carbon_Stored'
])

df_hrv
# Out:
#     Net_Carbon        Variable StandID MgmtID  Year
# 0     1.284222    505_2021_ASV     505    ASV  2021
# 1     4.206501    505_2025_ASV     505    ASV  2025
# 2     3.996429    505_2030_ASV     505    ASV  2030
# 3    31.035625    505_2050_ASV     505    ASV  2050
# 4    -1.660694    505_2021_IFM     505    IFM  2021
# 5     1.496395    505_2025_IFM     505    IFM  2025
# 6     3.317268    505_2030_IFM     505    IFM  2030
# 7    20.950588    505_2050_IFM     505    IFM  2050
# 8     0.000000   505_2021_PLSQ     505   PLSQ  2021
# 9     4.322262   505_2025_PLSQ     505   PLSQ  2025
# 10    5.055492   505_2030_PLSQ     505   PLSQ  2030
# 11   25.973648   505_2050_PLSQ     505   PLSQ  2050
# 12   -0.967472   505_2021_THNB     505   THNB  2021
# 13    1.413326   505_2025_THNB     505   THNB  2025
# 14    2.903717   505_2030_THNB     505   THNB  2030
# 15   27.720749   505_2050_THNB     505   THNB  2050
# 16  -11.714118    608_2021_AWR     608    AWR  2021
# 17   -5.682604    608_2025_AWR     608    AWR  2025
# 18   -0.463524    608_2030_AWR     608    AWR  2030
# 19   25.571611    608_2050_AWR     608    AWR  2050
# 20    0.000000   608_2021_PLSQ     608   PLSQ  2021
# 21    3.243416   608_2025_PLSQ     608   PLSQ  2025
# 22    3.187153   608_2030_PLSQ     608   PLSQ  2030
# 23   15.234692   608_2050_PLSQ     608   PLSQ  2050
# 24   -1.395567    999_2021_AWR     999    AWR  2021
# 25   -0.463110    999_2025_AWR     999    AWR  2025
# 26    2.231233    999_2030_AWR     999    AWR  2030
# 27   23.561516    999_2050_AWR     999    AWR  2050
# 28   -1.395567    999_2021_CAR     999    CAR  2021
# 29   -0.706893    999_2025_CAR     999    CAR  2025
# 30    0.822885    999_2030_CAR     999    CAR  2030
# 31   18.675200    999_2050_CAR     999    CAR  2050
# 32   -1.392861    999_2021_NAR     999    NAR  2021
# 33   -0.900875    999_2025_NAR     999    NAR  2025
# 34    0.184769    999_2030_NAR     999    NAR  2030
# 35   15.447171    999_2050_NAR     999    NAR  2050
# 36    0.000000   999_2021_PLSQ     999   PLSQ  2021
# 37   -0.101026   999_2025_PLSQ     999   PLSQ  2025
# 38    0.098066   999_2030_PLSQ     999   PLSQ  2030
# 39    1.249969   999_2050_PLSQ     999   PLSQ  2050
# 40   -1.395567    999_2021_SAR     999    SAR  2021
# 41   -0.635398    999_2025_SAR     999    SAR  2025
# 42    1.112241    999_2030_SAR     999    SAR  2030
# 43   20.716050    999_2050_SAR     999    SAR  2050
# 44    0.000000  167N_2021_PLSQ    167N   PLSQ  2021
# 45    1.848362  167N_2025_PLSQ    167N   PLSQ  2025
# 46   -0.386124  167N_2030_PLSQ    167N   PLSQ  2030
# 47    6.949192  167N_2050_PLSQ    167N   PLSQ  2050
# 48   -0.457464  167N_2021_THNB    167N   THNB  2021
# 49    1.044975  167N_2025_THNB    167N   THNB  2025
# 50    1.089890  167N_2030_THNB    167N   THNB  2030
# 51   21.187469  167N_2050_THNB    167N   THNB  2050
# 52    0.000000  167S_2021_PLSQ    167S   PLSQ  2021
# 53    5.697899  167S_2025_PLSQ    167S   PLSQ  2025
# 54    6.045704  167S_2030_PLSQ    167S   PLSQ  2030
# 55   14.331242  167S_2050_PLSQ    167S   PLSQ  2050
# 56   -0.759386  167S_2021_THNB    167S   THNB  2021
# 57    0.696815  167S_2025_THNB    167S   THNB  2025
# 58    1.144730  167S_2030_THNB    167S   THNB  2030
# 59   24.205189  167S_2050_THNB    167S   THNB  2050

# %%
df_hrv.to_csv('./run4_correctcarboncosts/Objective_NetSeq_NoHarvest_08172022.csv',
             columns=['Variable', 'Net_Carbon'],
             index=False
             )

# %% [markdown]
# ## Step 3 - Functions for Incorporating Costs
# Our plan is to create 100s of obj files with differing costs. This section makes
# some functions to build dataframes corresponding to the objective files.

# %%
# These are NOT real values
# they are intended to test functions and are purposely
# absurd
COSTS_DICT = {
    '167N': {
        'PLSQ': -10,
        'THNB': 10
    },
    '167S': {
        'PLSQ': 0,
        'THNB': 10
    },
    '505': {
        'PLSQ': 0,
        'ASV': 6.5,
        'IFM': 4.20,
        'THNB': 10
    },
    '608': {
        'PLSQ': 0,
        'AWR': 0
    },
    '999': {
        'PLSQ': 0,
        'AWR': 43,
        'CAR': 12,
        'NAR': 4,
        'SAR': 6
    }
}

# %%
def create_dataframe_from_costs (cost_dict: dict) -> dict:
    # The format of the dict isn't actually all that good for converting to a dataframe
    # so we need some ~finangeling~ for it to work    
    pd_dict = {
        'StandID': [],
        'MgmtID': [],
        'Year': [],
        'Mgmt_Cost': []
    }

    for_types = cost_dict.keys()
    for f in for_types:
        mgmts = cost_dict[f].keys()
        for mg in mgmts:
            cost = cost_dict[f][mg]

            pd_dict['StandID'].append(f)
            pd_dict['MgmtID'].append(mg)
            pd_dict['Year'].append(2021)
            pd_dict['Mgmt_Cost'].append(cost)
    
    _df = pd.DataFrame.from_dict(pd_dict)
    return _df

create_dataframe_from_costs(COSTS_DICT)
# Out:
#    StandID MgmtID  Year  Mgmt_Cost
# 0     167N   PLSQ  2021          0
# 1     167N   THNB  2021         10
# 2     167S   PLSQ  2021          0
# 3     167S   THNB  2021         10
# 4      505   PLSQ  2021          0
# 5      505    ASV  2021          0
# 6      505    IFM  2021          0
# 7      505   THNB  2021         10
# 8      608   PLSQ  2021          0
# 9      608    AWR  2021          0
# 10     999   PLSQ  2021          0
# 11     999    AWR  2021          0
# 12     999    CAR  2021          0
# 13     999    NAR  2021          0
# 14     999    SAR  2021          0

# %%
# Function to subtract a costs dictionary from a dataframe
def subtract_costs_dict (_df_all, _cost_dict: dict):
    '''
    Returns a copy of the df_all, but where the 'Net_Carbon' column
    had the management costs in df_costs removed.
    '''
    _df_all = _df_all.astype({'StandID': str})
    
    _df_costs = create_dataframe_from_costs(_cost_dict)
    
    # The underscores in front of the variables is to avoid any scope
    # ex: df_mgcosts exists outside this function, so using _df_mgcosts removes
    #     the possibility of editing the outside-function df
    _df_mgcost = _df_all.merge(
        _df_costs,
        how='left',
        on=['StandID', 'MgmtID', 'Year'],
        validate='one_to_one'
    )
    _df_mgcost = _df_mgcost.fillna(0)
    
    _df_mgcost['Net_Carbon'] = _df_mgcost['Net_Carbon'] - _df_mgcost['Mgmt_Cost']
#     _df_mgcost = _df_mgcost.drop(columns=['Mgmt_Cost'])
    
    return _df_mgcost

subtract_costs_dict(df_hrv, COSTS_DICT)
# Out:
#     Net_Carbon        Variable StandID MgmtID  Year  Mgmt_Cost
# 0    -5.215778    505_2021_ASV     505    ASV  2021        6.5
# 1     4.206501    505_2025_ASV     505    ASV  2025        0.0
# 2     3.996429    505_2030_ASV     505    ASV  2030        0.0
# 3    31.035625    505_2050_ASV     505    ASV  2050        0.0
# 4    -5.860694    505_2021_IFM     505    IFM  2021        4.2
# 5     1.496395    505_2025_IFM     505    IFM  2025        0.0
# 6     3.317268    505_2030_IFM     505    IFM  2030        0.0
# 7    20.950588    505_2050_IFM     505    IFM  2050        0.0
# 8     0.000000   505_2021_PLSQ     505   PLSQ  2021        0.0
# 9     4.322262   505_2025_PLSQ     505   PLSQ  2025        0.0
# 10    5.055492   505_2030_PLSQ     505   PLSQ  2030        0.0
# 11   25.973648   505_2050_PLSQ     505   PLSQ  2050        0.0
# 12  -10.967472   505_2021_THNB     505   THNB  2021       10.0
# 13    1.413326   505_2025_THNB     505   THNB  2025        0.0
# 14    2.903717   505_2030_THNB     505   THNB  2030        0.0
# 15   27.720749   505_2050_THNB     505   THNB  2050        0.0
# 16  -11.714118    608_2021_AWR     608    AWR  2021        0.0
# 17   -5.682604    608_2025_AWR     608    AWR  2025        0.0
# 18   -0.463524    608_2030_AWR     608    AWR  2030        0.0
# 19   25.571611    608_2050_AWR     608    AWR  2050        0.0
# 20    0.000000   608_2021_PLSQ     608   PLSQ  2021        0.0
# 21    3.243416   608_2025_PLSQ     608   PLSQ  2025        0.0
# 22    3.187153   608_2030_PLSQ     608   PLSQ  2030        0.0
# 23   15.234692   608_2050_PLSQ     608   PLSQ  2050        0.0
# 24  -44.395567    999_2021_AWR     999    AWR  2021       43.0
# 25   -0.463110    999_2025_AWR     999    AWR  2025        0.0
# 26    2.231233    999_2030_AWR     999    AWR  2030        0.0
# 27   23.561516    999_2050_AWR     999    AWR  2050        0.0
# 28  -13.395567    999_2021_CAR     999    CAR  2021       12.0
# 29   -0.706893    999_2025_CAR     999    CAR  2025        0.0
# 30    0.822885    999_2030_CAR     999    CAR  2030        0.0
# 31   18.675200    999_2050_CAR     999    CAR  2050        0.0
# 32   -5.392861    999_2021_NAR     999    NAR  2021        4.0
# 33   -0.900875    999_2025_NAR     999    NAR  2025        0.0
# 34    0.184769    999_2030_NAR     999    NAR  2030        0.0
# 35   15.447171    999_2050_NAR     999    NAR  2050        0.0
# 36    0.000000   999_2021_PLSQ     999   PLSQ  2021        0.0
# 37   -0.101026   999_2025_PLSQ     999   PLSQ  2025        0.0
# 38    0.098066   999_2030_PLSQ     999   PLSQ  2030        0.0
# 39    1.249969   999_2050_PLSQ     999   PLSQ  2050        0.0
# 40   -7.395567    999_2021_SAR     999    SAR  2021        6.0
# 41   -0.635398    999_2025_SAR     999    SAR  2025        0.0
# 42    1.112241    999_2030_SAR     999    SAR  2030        0.0
# 43   20.716050    999_2050_SAR     999    SAR  2050        0.0
# 44   10.000000  167N_2021_PLSQ    167N   PLSQ  2021      -10.0
# 45    1.848362  167N_2025_PLSQ    167N   PLSQ  2025        0.0
# 46   -0.386124  167N_2030_PLSQ    167N   PLSQ  2030        0.0
# 47    6.949192  167N_2050_PLSQ    167N   PLSQ  2050        0.0
# 48  -10.457464  167N_2021_THNB    167N   THNB  2021       10.0
# 49    1.044975  167N_2025_THNB    167N   THNB  2025        0.0
# 50    1.089890  167N_2030_THNB    167N   THNB  2030        0.0
# 51   21.187469  167N_2050_THNB    167N   THNB  2050        0.0
# 52    0.000000  167S_2021_PLSQ    167S   PLSQ  2021        0.0
# 53    5.697899  167S_2025_PLSQ    167S   PLSQ  2025        0.0
# 54    6.045704  167S_2030_PLSQ    167S   PLSQ  2030        0.0
# 55   14.331242  167S_2050_PLSQ    167S   PLSQ  2050        0.0
# 56  -10.759386  167S_2021_THNB    167S   THNB  2021       10.0
# 57    0.696815  167S_2025_THNB    167S   THNB  2025        0.0
# 58    1.144730  167S_2030_THNB    167S   THNB  2030        0.0
# 59   24.205189  167S_2050_THNB    167S   THNB  2050        0.0

# %% [markdown]
# ## Step 4 - Exporting a Buttload of Objective Files
# This is not an exaggeration, https://people.howstuffworks.com/buttload.htm
#
# In this section, we auto-generate 100s of objective files by varying different costs of managements.
#
# To show another capabability, we afterwards fix the cost of a management and vary the harvest carbon,
# again generating 100s of objective files.
#
# Would be interesting also to see the regions (2D, 3D, 4D etc) grid where PLSQ is preffered to management
# See: https://plotly.com/python/trisurf/

# %%
# df_mgcost.to_csv('./ObjectiveFile_MngCost_0802022.csv',
#               columns=['Variable', 'Net_Carbon'],
#               index=False
#              )

# %%
MNGS
# Out:
# ['AWR', 'NAR', 'THNB', 'CAR', 'SAR', 'PLSQ', 'ASV', 'IFM']

# %% [markdown]
# Here's how I want to try sampling different costs:
#
# - **167N** the cost of THNB to be inside the interval \[-1, 10\]
# - **505** is tricky as there are 3 different managements, so we can take a cube where the cost for each type ranges from \[-1, 10\]. Alternatively we can vary each one individually.
# - **608** has just one mng, AWR
# - **999** again has a couple managements. We have AWR, CAR, NAR, SAR, all of which we can range from \[-1, 10\]
#
# When a management is not the active one being managed, we set the cost of all others to 10 (except PLSQ which is always 0)
#
# For each interval, I want to take at least 100 samples. This means overall we're making 400 objective files (999 has 4 different costs that need varying).

# %%
SAMPLES_PER_MNG = 100
COST_LOW = -1
COST_HIGH = 20
COST_CANCELOUT = 1000
# The managements to vary the cost of
MNGS_DICT = {
    '167N': ['THNB'],
    '167S': ['THNB'],
    '505': ['ASV', 'IFM', 'THNB'],
    '608': ['AWR'],
    '999': ['AWR', 'CAR', 'NAR', 'SAR']
}

OBJ_EXPORT_FOLDER = '/home/velcro/Documents/Professional/NJDEP/TechWork/ForMOM/minimodel-running/run4_correctcarboncosts/objectives/'
COST_EXPORT_FOLDER = '/home/velcro/Documents/Professional/NJDEP/TechWork/ForMOM/minimodel-running/run4_correctcarboncosts/'

# %%
# Now comes the fun part of actually doing this
max_number_mngs = max([len(MNGS_DICT[str(ft)]) for ft in FOR_TYPES])
total_num_samples = max_number_mngs * SAMPLES_PER_MNG

total_num_samples
# Out:
# 1600

# %%
samples_per_ft_per_mng = {}

for ft in FOR_TYPES:
    ft = str(ft)
    
    num_mng = len(MNGS_DICT[ft])
    sample_per_mng = total_num_samples // num_mng
    # It's important we get exactly total_num_samples datapoints,
    # so the samples for the last mng might have a little extra
    sample_last_mng = total_num_samples - (num_mng - 1) * sample_per_mng
    
    ft_mngs = MNGS_DICT[ft]
    ft_num_mngs_dict = {}
    
    for ind, mng in enumerate(ft_mngs):
        if ind == num_mng - 1:
            ft_num_mngs_dict[mng] = sample_last_mng
        else:
            ft_num_mngs_dict[mng] = sample_per_mng
    
#     print(f"For ft {ft}, we have the following # samples per mng")
#     print(ft_num_mngs_dict)
#     print()
    samples_per_ft_per_mng[ft] = ft_num_mngs_dict

samples_per_ft_per_mng
# Out:
# {'608': {'AWR': 1600},
#  '999': {'AWR': 400, 'CAR': 400, 'NAR': 400, 'SAR': 400},
#  '167S': {'THNB': 1600},
#  '167N': {'THNB': 1600},
#  '505': {'ASV': 533, 'IFM': 533, 'THNB': 534}}

# %%
# Generate dictionary of parallel arrays showing the costs in each run

costs_across_runs = {}
for ft in FOR_TYPES:
    ft = str(ft)
    costs_across_runs[ft] = {}
    
    # PLSQ is always 0 cost
    costs_across_runs[ft]['PLSQ'] = list(np.linspace(0, 0, num=total_num_samples, endpoint=True))
    sum_inds = 0
    
    for mng in MNGS_DICT[ft]:
        costs_across_runs[ft][mng] = list(np.linspace(
            COST_CANCELOUT, 
            COST_CANCELOUT, 
            num=total_num_samples, 
            endpoint=True
        ))
        
        n_sample = samples_per_ft_per_mng[ft][mng]
        start_ind = sum_inds
        end_ind = start_ind + n_sample
        
        costs_across_runs[ft][mng][start_ind:end_ind] = list(np.linspace(
            COST_LOW,
            COST_HIGH,
            num=n_sample,
            endpoint=True
        ))
        
        # This needs to be at the end
        sum_inds = end_ind


pprint(costs_across_runs, depth=2)
costs_across_runs['505']['IFM']
# Out:
# {'167N': {'PLSQ': [...], 'THNB': [...]},
#  '167S': {'PLSQ': [...], 'THNB': [...]},
#  '505': {'ASV': [...], 'IFM': [...], 'PLSQ': [...], 'THNB': [...]},
#  '608': {'AWR': [...], 'PLSQ': [...]},
#  '999': {'AWR': [...], 'CAR': [...], 'NAR': [...], 'PLSQ': [...], 'SAR': [...]}}
# [1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#
#  15.578947368421051,
#  15.618421052631579,
#  15.657894736842103,
#  15.69736842105263,
#  15.736842105263158,
#  15.776315789473685,
#  15.815789473684209,
#  15.855263157894736,
#  15.894736842105264,
#  15.934210526315788,
#  15.973684210526315,
#  16.013157894736842,
#  16.052631578947366,
#  16.092105263157894,
#  16.13157894736842,
#  16.171052631578945,
#  16.210526315789473,
#  16.25,
#  16.289473684210524,
#  16.32894736842105,
#  16.36842105263158,
#  16.407894736842103,
#  16.44736842105263,
#  16.486842105263158,
#  16.526315789473685,
#  16.56578947368421,
#  16.605263157894736,
#  16.644736842105264,
#  16.684210526315788,
#  16.723684210526315,
#  16.763157894736842,
#  16.802631578947366,
#  16.842105263157894,
#  16.88157894736842,
#  16.921052631578945,
#  16.960526315789473,
#  17.0,
#  17.039473684210524,
#  17.07894736842105,
#  17.11842105263158,
#  17.157894736842103,
#  17.19736842105263,
#  17.236842105263158,
#  17.276315789473685,
#  17.31578947368421,
#  17.355263157894736,
#  17.394736842105264,
#  ...]

# %%
# Now, build the objective files!
# This means, for each sample, we build a COST_DICT, make a dataframe from it, and export
all_costs = []

for ind in range(total_num_samples):
    baseline_costs = {}
    
    for ft in FOR_TYPES:
        ft = str(ft)
        baseline_costs[ft] = {}
        mngs = costs_across_runs[ft].keys()
        
        for mng in mngs:
            baseline_costs[ft][mng] = costs_across_runs[ft][mng][ind]
    all_costs.append(baseline_costs)
    
    df_objective = subtract_costs_df(df_hrv, baseline_costs)
    
    # Export this objective file
    filename = f'ObjectiveFile_VaryingCost_0802022_{ind}.csv'
    df_objective.to_csv(
        OBJ_EXPORT_FOLDER + filename,
        columns=['Variable', 'Net_Carbon'],
        index=False
    )

# %%
# To make exporting the costs easier, a dataframe is constructed

# This is what the dataframe will look like:
#
# run  StandID  MgmtID  Mgmt_Cost
# 0    167N     PLSQ    0
# 0    167N     THNB    -1
# 0    167S     PLSQ    0
#  .     .       .      .
#  .     .       .      .
#  .     .       .      .
# 235  999      Nar    2.88
# 235  505      IFM    7.5
# 235  505      THNB   10.0
# 235  505      PLSQ   10.0
df_costs_all_runs = None

for ind, costs in enumerate(all_costs):
    df_indcost = create_dataframe_from_costs(costs)
    df_indcost.insert(loc=0, column='Run', value=ind)
    
    if type(df_costs_all_runs) == type(None):
        df_costs_all_runs = df_indcost
    else:
        df_costs_all_runs = pd.concat([df_costs_all_runs, df_indcost])

df_costs_all_runs.to_csv(COST_EXPORT_FOLDER + 'RunCosts.csv')
        
df_costs_all_runs
# Out:
#     Run StandID MgmtID  Year  Mgmt_Cost
# 0     0     608   PLSQ  2021        0.0
# 1     0     608    AWR  2021       -1.0
# 2     0     999   PLSQ  2021        0.0
# 3     0     999    AWR  2021       -1.0
# 4     0     999    CAR  2021     1000.0
# ..  ...     ...    ...   ...        ...
# 10  399    167N   THNB  2021       10.0
# 11  399     505   PLSQ  2021        0.0
# 12  399     505    ASV  2021     1000.0
# 13  399     505    IFM  2021     1000.0
# 14  399     505   THNB  2021       10.0
#
# [6000 rows x 5 columns]
